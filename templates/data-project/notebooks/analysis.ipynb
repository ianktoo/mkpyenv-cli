# %% [markdown]
# # {{PROJECT_NAME}} Analysis
# ## Instructions
# 1. Place your raw data in `../data/raw`
# 2. Load environment variables from `.env`
# 3. Import custom logic from `../src`

# %%
import sys
import os
# Add src to path so we can import internal libraries
sys.path.append(os.path.abspath('../src'))

from utils import hello_data
hello_data()
